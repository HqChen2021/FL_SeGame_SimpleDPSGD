# %%
# %run FL_main.py
# Out:
# Experimental details:
#     Model     : mlp
#     Optimizer : sgd
#     Learning  : 0.01
#     Global Rounds   : 10
#
#     Federated parameters:
#     IID
#     Fraction of users  : 0.5
#     Local Batch size   : 10
#     Local Epochs       : 10
#
# MLP(
#   (layer_input): Linear(in_features=784, out_features=64, bias=True)
#   (relu): ReLU()
#   (dropout): Dropout(p=0.5, inplace=False)
#   (layer_hidden): Linear(in_features=64, out_features=10, bias=True)
#   (softmax): Softmax(dim=1)
# )
#   0%|                                                                | 0/10 [00:00<?, ?it/s]
#  | Global Training Round : 1 |
#
# ...
# 1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/FLProject/FL_main.py in <module>
#      79             print(train_dataset+'\n')
#      80             print(idx)
# ...

# %%
# %run FL_main.py
# Out:
# Experimental details:
#     Model     : mlp
#     Optimizer : sgd
#     Learning  : 0.01
#     Global Rounds   : 10
#
#     Federated parameters:
#     IID
#     Fraction of users  : 0.5
#     Local Batch size   : 10
#     Local Epochs       : 10
#
# MLP(
#   (layer_input): Linear(in_features=784, out_features=64, bias=True)
#   (relu): ReLU()
#   (dropout): Dropout(p=0.5, inplace=False)
#   (layer_hidden): Linear(in_features=64, out_features=10, bias=True)
#   (softmax): Softmax(dim=1)
# )
#   0%|                                                                | 0/10 [00:00<?, ?it/s]
#  | Global Training Round : 1 |
#
# ...

# %%
# %run FL_main.py
# Out:
# Experimental details:
#     Model     : mlp
#     Optimizer : sgd
#     Learning  : 0.01
#     Global Rounds   : 10
#
#     Federated parameters:
#     IID
#     Fraction of users  : 0.5
#     Local Batch size   : 10
#     Local Epochs       : 10
#
# MLP(
#   (layer_input): Linear(in_features=784, out_features=64, bias=True)
#   (relu): ReLU()
#   (dropout): Dropout(p=0.5, inplace=False)
#   (layer_hidden): Linear(in_features=64, out_features=10, bias=True)
#   (softmax): Softmax(dim=1)
# )
#   0%|                                                                | 0/10 [00:00<?, ?it/s]
#  | Global Training Round : 1 |
#
# ...
